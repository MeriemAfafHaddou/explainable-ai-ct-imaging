# %% [markdown]
# # Exploring the Feasibility of Data Augmentation for ICH Classification

# %% [markdown]
# # 1. Objective
#
# This notebook investigates whether **data augmentation is a feasible strategy for improving ICH classification** in the current brain CT dataset.
#
# The goal is not to assume that augmentation will improve the model, but to evaluate its potential through controlled experiments while keeping the existing baseline setup unchanged.
#
# ---
#
# # 2. Motivation
#
# The current classifier shows **limited ICH sensitivity** despite relatively high specificity. Since the dataset is also relatively small, increasing the variability of training images through augmentation could potentially improve generalization.
#
# This notebook therefore explores whether **conservative, medically plausible transformations** can provide useful additional variation during training.

# %% [markdown]
# # 3. Augmentation Strategy

# %% [markdown]
# # 4. Visualizing the Augmentations

# %% [markdown]
# # 5. Experimental Setup

# %% [markdown]
# # 6. Comparison with the Baseline

# %% [markdown]
# # 7. Final Model Experiment

# %% [markdown]
# # 8. Interpretation & Limitations

# %% [markdown]
# # 9. Conclusion
